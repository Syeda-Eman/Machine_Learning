# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/Machine_Learning/blob/main/Riyadh_housing_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
syedaeman2212_riyadh_housing_prices_path = kagglehub.dataset_download('syedaeman2212/riyadh-housing-prices')

print('Data source import complete.')

# %% [markdown]
# <a href="https://colab.research.google.com/github/Syeda-Eman/Machine_Learning/blob/main/Boston_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Dependencies**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %% [markdown]
# # **Importing data**

# %%
df = pd.read_csv('/kaggle/input/riyadh-housing-prices/riyadh_housing_prices_synthetic.csv')

# %%
df.head()

# %%
df.describe()

# %% [markdown]
# # **Splitting data**

# %%
X = df.drop(['Total_Price_SAR', 'District'], axis=1)
y = df['Total_Price_SAR']

# %%
print(X)
print(y)

# %%
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)

# %% [markdown]
# # **Model Training**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)

# %% [markdown]
# # **Evaluation**

# %%
training_data_pred = model.predict(X_train)

# %%
print(training_data_pred)

# %%
#R squared error
score_1 = metrics.r2_score(y_train, training_data_pred)

print("R squared error: ", score_1)

# %% [markdown]
# # **Visualizing actual prices and predicted prices (Training)**

# %%
plt.scatter(y_train, training_data_pred)
plt.xlabel('Actual prices')
plt.ylabel('Predicted prices')
plt.title('Actual price vs predicted prices')
plt.show()

# %% [markdown]
# # **Prediction on test data**

# %%
test_data_pred = model.predict(X_test)

# %%
#R squared error
score_1 = metrics.r2_score(y_test, test_data_pred)

print("R squared error: ", score_1)

# %% [markdown]
# # **Visualizing actual prices and predicted prices (Testing)**

# %%
plt.scatter(y_test, test_data_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted prices")
plt.show()
